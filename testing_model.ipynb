# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df =pd.read_csv('testing(1).csv')

df.head()
# Out:
#    S/N      Name               Email Address Lesson Summary  Quiz Summary  \
# 0    1    Sophie       scaddies0@webnode.com            3/7          70.6
# 1    2     Helge     hblakeley1@hubpages.com            3/7          19.1
# 2    3    Benson      bspencelayh2@vimeo.com            3/7          97.6
# 3    4  Clarance  cabramowsky3@csmonitor.com            1/7           1.7
# 4    5  Marcille     mmatresse4@addtoany.com            5/7          26.3
#
#    Assignment Summary  Grade Point Average  Intermediate class Eligibility
# 0                  36                48.93                            True
# 1                  17                 1.03                           False
# 2                  60                46.14                           False
# 3                  89                54.90                            True
# 4                  24                77.57                           False

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   S/N                             1000 non-null   int64
#  1   Name                            1000 non-null   object
#  2   Email Address                   1000 non-null   object
#  3   Lesson Summary                  1000 non-null   object
#  4   Quiz Summary                    1000 non-null   float64
#  5   Assignment Summary              1000 non-null   int64
#  6   Grade Point Average             1000 non-null   float64
#  7   Intermediate class Eligibility  1000 non-null   bool
# dtypes: bool(1), float64(2), int64(2), object(3)
# memory usage: 55.8+ KB

# %%
df.isna().sum()
# Out:
# S/N                               0
# Name                              0
# Email Address                     0
# Lesson Summary                    0
# Quiz Summary                      0
# Assignment Summary                0
# Grade Point Average               0
# Intermediate class Eligibility    0
# dtype: int64

# %%
def student(column):
    if column >=50 :
        return 'Yes'
    else:
        return 'No'

# %%
df['Intermediate class Eligibility'] = df['Grade Point Average'].apply(student)

df
# Out:
#       S/N      Name                 Email Address Lesson Summary  \
# 0       1    Sophie         scaddies0@webnode.com            3/7
# 1       2     Helge       hblakeley1@hubpages.com            3/7
# 2       3    Benson        bspencelayh2@vimeo.com            3/7
# 3       4  Clarance    cabramowsky3@csmonitor.com            1/7
# 4       5  Marcille       mmatresse4@addtoany.com            5/7
# ..    ...       ...                           ...            ...
# 995   996      Nike         nhandrickrn@salon.com            1/7
# 996   997    Godard  gthwaitesro@biblegateway.com            7/7
# 997   998    Melina          msmizrp@vkontakte.ru            5/7
# 998   999    Catlee      cwinsletrq@over-blog.com            7/7
# 999  1000     Johan       jkopmannrr@facebook.com            1/7
#
#      Quiz Summary  Assignment Summary  Grade Point Average  \
# 0            70.6                  36                48.93
# 1            19.1                  17                 1.03
# ...

# %%
## Coverting our Intermediate class Eligibility column to binary

df["Intermediate class Eligibility"].replace({'Yes' : 1,'No' : 0},inplace=True)

df.head()
# Out:
#    S/N      Name               Email Address Lesson Summary  Quiz Summary  \
# 0    1    Sophie       scaddies0@webnode.com            3/7          70.6
# 1    2     Helge     hblakeley1@hubpages.com            3/7          19.1
# 2    3    Benson      bspencelayh2@vimeo.com            3/7          97.6
# 3    4  Clarance  cabramowsky3@csmonitor.com            1/7           1.7
# 4    5  Marcille     mmatresse4@addtoany.com            5/7          26.3
#
#    Assignment Summary  Grade Point Average  Intermediate class Eligibility
# 0                  36                48.93                               0
# 1                  17                 1.03                               0
# 2                  60                46.14                               0
# 3                  89                54.90                               1
# 4                  24                77.57                               1

# %%
df.describe()
# Out:
#                S/N  Quiz Summary  Assignment Summary  Grade Point Average  \
# count  1000.000000   1000.000000          1000.00000          1000.000000
# mean    500.500000     52.608700            51.39000            50.260930
# std     288.819436     28.389085            28.73586            29.038293
# min       1.000000      1.000000             1.00000             1.030000
# 25%     250.750000     28.375000            27.00000            25.102500
# 50%     500.500000     53.150000            52.00000            49.985000
# 75%     750.250000     77.800000            76.00000            76.307500
# max    1000.000000     99.900000           100.00000            99.990000
#
#        Intermediate class Eligibility
# count                      1000.00000
# mean                          0.50000
# std                           0.50025
# min                           0.00000
# 25%                           0.00000
# 50%                           0.50000
# ...

# %%
# lets drop the colums we dont need
df.drop(['Name','Email Address', 'Lesson Summary', 'S/N'], axis=1, inplace= True)

df.head()
# Out:
#    Quiz Summary  Assignment Summary  Grade Point Average  \
# 0          70.6                  36                48.93
# 1          19.1                  17                 1.03
# 2          97.6                  60                46.14
# 3           1.7                  89                54.90
# 4          26.3                  24                77.57
#
#    Intermediate class Eligibility
# 0                               0
# 1                               0
# 2                               0
# 3                               1
# 4                               1

# %%
df.drop(['Intermediate class Eligibility'], axis=1, inplace= True)

df.head()
# Out:
#    Quiz Summary  Assignment Summary  Grade Point Average
# 0          70.6                  36                48.93
# 1          19.1                  17                 1.03
# 2          97.6                  60                46.14
# 3           1.7                  89                54.90
# 4          26.3                  24                77.57

# %%
import joblib

model = joblib.load('LR_model.joblib')

prediction = model.predict(df)
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# /home/tina/my_project/testing_model.ipynb Cell 11 in <cell line: 5>()
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/tina/my_project/testing_model.ipynb#X13sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> import joblib
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/tina/my_project/testing_model.ipynb#X13sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a> model = joblib.load('LR_model.joblib')
# ----> <a href='vscode-notebook-cell://wsl%2Bubuntu/home/tina/my_project/testing_model.ipynb#X13sdnNjb2RlLXJlbW90ZQ%3D%3D?line=4'>5</a> prediction = model.predict(df)
#
# File ~/.local/lib/python3.8/site-packages/sklearn/linear_model/_base.py:419, in LinearClassifierMixin.predict(self, X)
#     405 """
#     406 Predict class labels for samples in X.
#     407
#    (...)
#     416     Vector containing the class labels for each sample.
# ...

# %%
import joblib

# Load the logistic regression model from the saved file
model = joblib.load('LR_model.joblib')

# Fit the model on training data before making predictions
model.fit(x_train, y_train)

# Make predictions on the new dataset
predictions = model.predict(df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /home/tina/my_project/testing_model.ipynb Cell 12 in <cell line: 7>()
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/tina/my_project/testing_model.ipynb#X14sdnNjb2RlLXJlbW90ZQ%3D%3D?line=3'>4</a> model = joblib.load('LR_model.joblib')
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/tina/my_project/testing_model.ipynb#X14sdnNjb2RlLXJlbW90ZQ%3D%3D?line=5'>6</a> # Fit the model on training data before making predictions
# ----> <a href='vscode-notebook-cell://wsl%2Bubuntu/home/tina/my_project/testing_model.ipynb#X14sdnNjb2RlLXJlbW90ZQ%3D%3D?line=6'>7</a> model.fit(x_train, y_train)
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/tina/my_project/testing_model.ipynb#X14sdnNjb2RlLXJlbW90ZQ%3D%3D?line=8'>9</a> # Make predictions on the new dataset
# ...
